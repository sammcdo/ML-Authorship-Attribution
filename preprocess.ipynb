# %% [markdown]
# # Authorship Attribution Petition

# %% [markdown]
# Sam McDowell \
# 12/5/2025

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Imports

# %%
# %pip install spacy
import sys
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.10.5)
# Requirement already satisfied: jinja2 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (75.6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.3.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sam_m\appdata\local\programs\python\python313\lib\site-packages (from jinja2->spacy) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---- ----------------------------------- 1.3/12.8 MB 12.6 MB/s eta 0:00:01
#      ------------ --------------------------- 3.9/12.8 MB 12.5 MB/s eta 0:00:01
#      -------------------- ------------------- 6.6/12.8 MB 12.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 13.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 13.7 MB/s  0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# %load_ext autoreload
# %autoreload 1


# %aimport features

import pandas as pd
import re
import html
import spacy

import features
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\sam_m\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sam_m\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Load the Data

# %%
filepath = "./data/blog_authorship_corpus.csv"

df = pd.read_csv(filepath)

# %%
# drop unneeded columns
df = df.drop(["sign", "topic", "date", "gender", "age"], axis=1)

# %%
df.describe(include='all').T
# Out:
#          count  unique                  top freq            mean  \
# id    681284.0     NaN                  NaN  NaN  2397802.403396
# text    681284  611652           urlLink     445             NaN
#
#                  std     min        25%        50%        75%        max
# id    1247722.701325  5114.0  1239610.0  2607577.0  3525660.0  4337650.0
# text             NaN     NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ### Select Source Texts

# %%
df["text_len"] = df["text"].str.len()
df["word_count"] = df["text"].str.split().str.len()

# %% [markdown]
# Find the authors with the most long posts, take their longest posts

# %%
# count number of posts longer than 1k words for each user
long_counts = df[df['word_count'] >= 1000].groupby('id').size().rename('long_post_count')

# group by id, filter more than 40 long posts
group_stats = df.groupby('id')["word_count"].agg(["mean","count"]).rename(columns={"mean":"avg_word_count","count":"item_count"})
group_stats = group_stats.join(long_counts, how='left').fillna(0).astype({'long_post_count': int})
group_stats = group_stats[group_stats['long_post_count'] >= 40]
group_stats = group_stats.sort_values("long_post_count", ascending=False)
group_stats.head(50)

# select only 15 authors
group_stats = group_stats.head(15)

# %%
# select top 40 longest posts from the 15 authors
top_posts = (
    df[df['id'].isin(group_stats.index)]
    .sort_values(['id', 'word_count'], ascending=[True, False])
    .groupby('id')
    .head(40)
    .reset_index(drop=True)
)

top_posts.head(5)
# Out:
#        id                                               text  text_len  \
# 0  215223                I Can See Clearly Now  I went to...     11845
# 1  215223                Boozy Ol' Showgirl  My Gawd,  da...     10842
# 2  215223                The Long Goodbye  Over the weeke...     10177
# 3  215223                Warning:  Gay Homosexual Showtun...      9602
# 4  215223                Internal Inventory  I don't real...      8866
#
#    word_count
# 0        2177
# 1        1951
# 2        1911
# 3        1703
# 4        1630

# %%
top_posts.info()
top_posts.describe(include='all').T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          600 non-null    int64
#  1   text        600 non-null    object
#  2   text_len    600 non-null    int64
#  3   word_count  600 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 18.9+ KB
#             count unique                                                top  \
# id          600.0    NaN                                                NaN
# text          600    600            [You say] the UN is a useless club f...
# text_len    600.0    NaN                                                NaN
# word_count  600.0    NaN                                                NaN
#
#            freq            mean            std       min       25%        50%  \
# id          NaN  1630971.733333  960077.637048  215223.0  554681.0  1510754.0
# text          1             NaN            NaN       NaN       NaN        NaN
# text_len    NaN        12457.49   14829.426587    5409.0    7203.0     8890.0
# word_count  NaN     2238.733333     2749.80065    1023.0    1303.5     1603.0
#
#                   75%        max
# id          2639424.0  2922061.0
# text              NaN        NaN
# text_len      11906.5   274796.0
# word_count    2148.75    51835.0

# %%
filepath = "./data/selected_texts.csv"
top_posts.to_csv(filepath)

# %% [markdown]
# ### Preprocess Text

# %%
filepath = "./data/selected_texts.csv"
df = pd.read_csv(filepath, index_col=0)

# %%
# remove all characters except letters from each word
def keep_only_letters(s):
    tokens = []
    for w in s.split():
        # remove leading/trailing non-letters but keep internal characters (e.g. don't -> don't)
        w2 = re.sub(r'^[^A-Za-z]+|[^A-Za-z]+$', '', w)
        if re.search(r'[A-Za-z]', w2):
            tokens.append(w2)
    return " ".join(tokens)

# get number of sentences for each 
nlp = spacy.load("en_core_web_sm", disable=["tagger","parser","ner","lemmatizer"])
nlp.add_pipe("sentencizer")
def sentence_count(text):
    doc = nlp(text or "")
    return sum(1 for _ in doc.sents)


df["prp_text"] = df["text"].copy(deep=True)
# remove html special chars
df["prp_text"] = df["prp_text"].apply(lambda x: html.unescape(x)) 
# remove bad spaces
df["prp_text"] = df["prp_text"].apply(lambda x: x.replace("\u00A0", " ").replace("\xa0", " ")) 
# Remove 'urlLink
df["prp_text"] = df["text"].apply(lambda x: re.sub(r'urlLink', '', x).strip()) 
# remove non letter characters from words
df["prp_text"] = df["prp_text"].apply(keep_only_letters)
# Remove duplicate whitespace
df["prp_text"] = df["prp_text"].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

# keep only first 1000 words
df["prp_text"] = df["prp_text"].apply(lambda x: " ".join(x.split()[0:1000]))

df["text_len"] = df["prp_text"].str.len()
df["word_count"] = df["prp_text"].str.split().str.len()
df['sentence_count'] = df['text'].fillna("").apply(sentence_count)

df.describe(include='all')
# Out:
#                   id                                               text  \
# count   6.000000e+02                                                600
# unique           NaN                                                600
# top              NaN            [You say] the UN is a useless club f...
# freq             NaN                                                  1
# mean    1.630972e+06                                                NaN
# std     9.600776e+05                                                NaN
# min     2.152230e+05                                                NaN
# 25%     5.546810e+05                                                NaN
# 50%     1.510754e+06                                                NaN
# 75%     2.639424e+06                                                NaN
# max     2.922061e+06                                                NaN
#
#            text_len  word_count  \
# count    600.000000       600.0
# unique          NaN         NaN
# top             NaN         NaN
# freq            NaN         NaN
# mean    5370.171667      1000.0
# std      284.173027         0.0
# min     4764.000000      1000.0
# 25%     5153.500000      1000.0
# 50%     5321.000000      1000.0
# 75%     5581.250000      1000.0
# max     6157.000000      1000.0
#
#                                                  prp_text  sentence_count
# count                                                 600      600.000000
# unique                                                597             NaN
# top     Salon.com The confessions of a semi-successful...             NaN
# freq                                                    2             NaN
# mean                                                  NaN      146.433333
# std                                                   NaN      194.750795
# min                                                   NaN       14.000000
# 25%                                                   NaN       75.000000
# 50%                                                   NaN      101.000000
# 75%                                                   NaN      140.000000
# max                                                   NaN     3284.000000

# %%
# save preprocessing
filename = "./data/preprocessed.csv"
df.to_csv(filename)

# %% [markdown]
# ## Feature Engineering

# %%
df["words"] = df["prp_text"].str.split()
df["sentences"] = df["text"].apply(features._split_sentences)

f = pd.DataFrame()
f["author"] = df["id"]
f["word_count"] = df["word_count"]
f["sentence_count"] = df["sentence_count"]

f.describe(include='all')
# Out:
#              author  word_count  sentence_count
# count  6.000000e+02       600.0      600.000000
# mean   1.630972e+06      1000.0      146.433333
# std    9.600776e+05         0.0      194.750795
# min    2.152230e+05      1000.0       14.000000
# 25%    5.546810e+05      1000.0       75.000000
# 50%    1.510754e+06      1000.0      101.000000
# 75%    2.639424e+06      1000.0      140.000000
# max    2.922061e+06      1000.0     3284.000000

# %% [markdown]
# #### VOCABULARY

# %%
### VOCABULARY
f["type_token_ratio"] = df["words"].apply(lambda text: features.type_token_ratio(text))
f["vocab_size"] = df["words"].apply(lambda text: features.vocabulary_size(text))

f["stopword_ratio"] = df["words"].apply(features.stopword_ratio)

f["hapax_legomena_ratio"] = df["words"].apply(features.hapax_legomena)
f["hapax_dislegomena_ratio"] = df["words"].apply(features.hapax_dislegomena)

f.describe(include='all')
# Out:
#              author  word_count  sentence_count  type_token_ratio  vocab_size  \
# count  6.000000e+02       600.0      600.000000        600.000000  600.000000
# mean   1.630972e+06      1000.0      146.433333          0.471668  471.668333
# std    9.600776e+05         0.0      194.750795          0.052679   52.678998
# min    2.152230e+05      1000.0       14.000000          0.359000  359.000000
# 25%    5.546810e+05      1000.0       75.000000          0.434750  434.750000
# 50%    1.510754e+06      1000.0      101.000000          0.471500  471.500000
# 75%    2.639424e+06      1000.0      140.000000          0.505000  505.000000
# max    2.922061e+06      1000.0     3284.000000          0.652000  652.000000
#
#        stopword_ratio  hapax_legomena_ratio  hapax_dislegomena_ratio
# count      600.000000            600.000000               600.000000
# mean         0.494942              0.332532                 0.065158
# std          0.045516              0.059152                 0.007935
# min          0.341000              0.218000                 0.046000
# 25%          0.463750              0.289750                 0.060000
# 50%          0.500000              0.326500                 0.065000
# 75%          0.527000              0.368000                 0.070000
# max          0.604000              0.545000                 0.106000

# %% [markdown]
# #### READABILITY

# %%
### READABILITY
f["average_num_syllables"] = df["words"].apply(lambda text: features.average_syllables(text))
f["std_num_syllables"] = df["words"].apply(features.std_syllables)

f["average_sent_len"] = df.apply(lambda r: features.average_words_per_sentence(r["sentences"]), axis=1)
f["std_sent_len"] = df.apply(lambda r: features.std_sentence_length(r["sentences"]), axis=1)

f["average_syllables_vocabulary"] = df["words"].apply(lambda text: features.average_syllables_of_vocabulary(text))

f["average_word_len"] = df["words"].apply(features.average_word_len)
f["std_word_len"] = df["words"].apply(features.std_word_length)

# %%
f["flesch_reading_ease"] = df.apply(lambda r: features.flesch_reading_ease(r["sentences"], r["words"]), axis=1)
f["dale_chall_reading_ease"] = df.apply(lambda r: features.dale_chall_reading_ease(r["words"], r["sentence_count"]), axis=1)
f["gunning_fog_index"] = df.apply(lambda r: features.gunning_fog_index(r["words"], r["sentence_count"]), axis=1)

# %%
f.describe(include='all')
# Out:
#              author  word_count  sentence_count  type_token_ratio  vocab_size  \
# count  6.000000e+02       600.0      600.000000        600.000000  600.000000
# mean   1.630972e+06      1000.0      146.433333          0.471668  471.668333
# std    9.600776e+05         0.0      194.750795          0.052679   52.678998
# min    2.152230e+05      1000.0       14.000000          0.359000  359.000000
# 25%    5.546810e+05      1000.0       75.000000          0.434750  434.750000
# 50%    1.510754e+06      1000.0      101.000000          0.471500  471.500000
# 75%    2.639424e+06      1000.0      140.000000          0.505000  505.000000
# max    2.922061e+06      1000.0     3284.000000          0.652000  652.000000
#
#        stopword_ratio  hapax_legomena_ratio  hapax_dislegomena_ratio  \
# count      600.000000            600.000000               600.000000
# mean         0.494942              0.332532                 0.065158
# std          0.045516              0.059152                 0.007935
# min          0.341000              0.218000                 0.046000
# 25%          0.463750              0.289750                 0.060000
# 50%          0.500000              0.326500                 0.065000
# 75%          0.527000              0.368000                 0.070000
# max          0.604000              0.545000                 0.106000
#
#        average_num_syllables  std_num_syllables  average_sent_len  \
# count             600.000000         600.000000        600.000000
# mean                1.406312           0.734485         73.806723
# std                 0.100124           0.111353         29.585039
# min                 1.200000           0.481876         20.538244
# 25%                 1.335000           0.657450         55.554299
# 50%                 1.383000           0.718122         67.966235
# 75%                 1.473250           0.811875         85.744156
# max                 1.742000           1.205585        425.857143
#
#        std_sent_len  average_syllables_vocabulary  average_word_len  \
# count    600.000000                    600.000000        600.000000
# mean      53.630812                      1.669337          4.371172
# std       30.337447                      0.129046          0.284173
# min       22.375227                      1.382927          3.765000
# 25%       38.416563                      1.581531          4.154500
# 50%       48.777188                      1.648899          4.322000
# 75%       60.994252                      1.757138          4.582250
# max      378.189896                      2.103131          5.158000
#
#        std_word_len  flesch_reading_ease  dale_chall_reading_ease  \
# count    600.000000           600.000000               600.000000
# mean       2.388320            77.333621                19.940943
# std        0.272794            10.811252                 0.271680
# min        1.833030            16.487200                19.441604
# 25%        2.205810            70.556982                19.780786
# 50%        2.341955            78.527084                19.917589
# 75%        2.554922            85.437283                20.087833
# max        3.474147           102.975526                22.969357
#
#        gunning_fog_index
# count         600.000000
# mean            7.568934
# std             2.797765
# min             0.961803
# 25%             5.740444
# 50%             7.411930
# 75%             9.278414
# max            31.891429

# %% [markdown]
# #### POS Tagging

# %%
f_pos = df["words"].apply(features.pos_counts).apply(pd.Series)
f_pos.columns = [c.lower()+"_count" for c in f_pos.columns]

f_punc = df["text"].apply(features.punc_counts).apply(pd.Series)
f_punc.columns = [c.lower()+"_count" for c in f_punc.columns]

f_sent = df.apply(lambda r: features.sentence_type_counts(r["sentences"]), axis=1).apply(pd.Series)
f_sent.columns = [c.lower()+"_count" for c in f_sent.columns]

# %%
f = pd.concat([f,f_pos,f_punc,f_sent], axis=1)
f.describe(include='all')
# Out:
#              author  word_count  sentence_count  type_token_ratio  vocab_size  \
# count  6.000000e+02       600.0      600.000000        600.000000  600.000000
# mean   1.630972e+06      1000.0      146.433333          0.471668  471.668333
# std    9.600776e+05         0.0      194.750795          0.052679   52.678998
# min    2.152230e+05      1000.0       14.000000          0.359000  359.000000
# 25%    5.546810e+05      1000.0       75.000000          0.434750  434.750000
# 50%    1.510754e+06      1000.0      101.000000          0.471500  471.500000
# 75%    2.639424e+06      1000.0      140.000000          0.505000  505.000000
# max    2.922061e+06      1000.0     3284.000000          0.652000  652.000000
#
#        stopword_ratio  hapax_legomena_ratio  hapax_dislegomena_ratio  \
# count      600.000000            600.000000               600.000000
# mean         0.494942              0.332532                 0.065158
# std          0.045516              0.059152                 0.007935
# min          0.341000              0.218000                 0.046000
# 25%          0.463750              0.289750                 0.060000
# 50%          0.500000              0.326500                 0.065000
# 75%          0.527000              0.368000                 0.070000
# max          0.604000              0.545000                 0.106000
#
#        average_num_syllables  std_num_syllables  ...  propn_count   sym_count  \
# count             600.000000         600.000000  ...   600.000000  600.000000
# mean                1.406312           0.734485  ...    69.536667    0.546667
# std                 0.100124           0.111353  ...    45.414492    1.286045
# min                 1.200000           0.481876  ...     4.000000    0.000000
# 25%                 1.335000           0.657450  ...    40.000000    0.000000
# 50%                 1.383000           0.718122  ...    59.500000    0.000000
# 75%                 1.473250           0.811875  ...    90.000000    1.000000
# max                 1.742000           1.205585  ...   357.000000   14.000000
#
#           x_count  period_count  exclam_count  quest_count  simple_count  \
# count  600.000000    600.000000    600.000000   600.000000    600.000000
# mean     0.556667    187.118333      8.445000    11.751667     75.688333
# std      0.893375    221.852771     17.418361    17.760322    122.964487
# min      0.000000     27.000000      0.000000     0.000000      2.000000
# 25%      0.000000     87.000000      0.000000     3.000000     29.000000
# 50%      0.000000    118.500000      3.000000     7.000000     45.000000
# 75%      1.000000    196.250000     10.000000    14.000000     68.250000
# max      6.000000   2888.000000    217.000000   230.000000   1871.000000
#
#        compound_count  complex_count  compound_complex_count
# count      600.000000     600.000000              600.000000
# mean        20.443333      28.911667               21.390000
# std         24.361498      36.523149               18.462286
# min          0.000000       1.000000                4.000000
# 25%         10.000000      16.000000               14.000000
# 50%         15.000000      22.000000               18.000000
# 75%         22.000000      32.000000               23.000000
# max        370.000000     705.000000              338.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# #### SAVE

# %%
f.to_csv("./data/features.csv")
f.describe(include='all')
# Out:
#              author  word_count  sentence_count  type_token_ratio  vocab_size  \
# count  6.000000e+02       600.0      600.000000        600.000000  600.000000
# mean   1.630972e+06      1000.0      146.433333          0.471668  471.668333
# std    9.600776e+05         0.0      194.750795          0.052679   52.678998
# min    2.152230e+05      1000.0       14.000000          0.359000  359.000000
# 25%    5.546810e+05      1000.0       75.000000          0.434750  434.750000
# 50%    1.510754e+06      1000.0      101.000000          0.471500  471.500000
# 75%    2.639424e+06      1000.0      140.000000          0.505000  505.000000
# max    2.922061e+06      1000.0     3284.000000          0.652000  652.000000
#
#        stopword_ratio  hapax_legomena_ratio  hapax_dislegomena_ratio  \
# count      600.000000            600.000000               600.000000
# mean         0.494942              0.332532                 0.065158
# std          0.045516              0.059152                 0.007935
# min          0.341000              0.218000                 0.046000
# 25%          0.463750              0.289750                 0.060000
# 50%          0.500000              0.326500                 0.065000
# 75%          0.527000              0.368000                 0.070000
# max          0.604000              0.545000                 0.106000
#
#        average_num_syllables  std_num_syllables  ...  propn_count   sym_count  \
# count             600.000000         600.000000  ...   600.000000  600.000000
# mean                1.406312           0.734485  ...    69.536667    0.546667
# std                 0.100124           0.111353  ...    45.414492    1.286045
# min                 1.200000           0.481876  ...     4.000000    0.000000
# 25%                 1.335000           0.657450  ...    40.000000    0.000000
# 50%                 1.383000           0.718122  ...    59.500000    0.000000
# 75%                 1.473250           0.811875  ...    90.000000    1.000000
# max                 1.742000           1.205585  ...   357.000000   14.000000
#
#           x_count  period_count  exclam_count  quest_count  simple_count  \
# count  600.000000    600.000000    600.000000   600.000000    600.000000
# mean     0.556667    187.118333      8.445000    11.751667     75.688333
# std      0.893375    221.852771     17.418361    17.760322    122.964487
# min      0.000000     27.000000      0.000000     0.000000      2.000000
# 25%      0.000000     87.000000      0.000000     3.000000     29.000000
# 50%      0.000000    118.500000      3.000000     7.000000     45.000000
# 75%      1.000000    196.250000     10.000000    14.000000     68.250000
# max      6.000000   2888.000000    217.000000   230.000000   1871.000000
#
#        compound_count  complex_count  compound_complex_count
# count      600.000000     600.000000              600.000000
# mean        20.443333      28.911667               21.390000
# std         24.361498      36.523149               18.462286
# min          0.000000       1.000000                4.000000
# 25%         10.000000      16.000000               14.000000
# 50%         15.000000      22.000000               18.000000
# 75%         22.000000      32.000000               23.000000
# max        370.000000     705.000000              338.000000
#
# [8 rows x 38 columns]
